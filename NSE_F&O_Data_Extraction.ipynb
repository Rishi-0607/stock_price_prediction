# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishi-0607/stock_price_prediction/blob/main/NSE_F%26O_Data_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nselib

# %%
from nselib import derivatives

# %%
derivatives.expiry_dates_future()
# Out:
# ['25-Jan-2024', '29-Feb-2024', '28-Mar-2024']

# %%
derivatives.expiry_dates_option_index()
# Out:
# {'NIFTY': ['11-Jan-2024',
#   '18-Jan-2024',
#   '25-Jan-2024',
#   '01-Feb-2024',
#   '08-Feb-2024',
#   '29-Feb-2024',
#   '28-Mar-2024',
#   '27-Jun-2024',
#   '26-Sep-2024',
#   '26-Dec-2024',
#   '26-Jun-2025',
#   '24-Dec-2025',
#   '25-Jun-2026',
#   '31-Dec-2026',
#   '24-Jun-2027',
#   '30-Dec-2027',
#   '29-Jun-2028',
#   '28-Dec-2028'],
#  'FINNIFTY': ['09-Jan-2024',
#   '16-Jan-2024',
#   '23-Jan-2024',
#   '30-Jan-2024',
#   '06-Feb-2024',
#   '27-Feb-2024',
#   '26-Mar-2024'],
#  'BANKNIFTY': ['10-Jan-2024',
#   '17-Jan-2024',
#   '25-Jan-2024',
#   '31-Jan-2024',
#   '07-Feb-2024',
#   '29-Feb-2024',
#   '28-Mar-2024',
#   '27-Jun-2024',
#   '26-Sep-2024',
#   '26-Dec-2024']}

# %%
derivatives.fii_derivatives_statistics('05-01-2024')
# Out:
#        fii_derivatives  buy_contracts  buy_value_in_Cr  sell_contracts  \
# 0     FINNIFTY FUTURES          213.0            18.38           157.0
# 1    BANKNIFTY FUTURES        20864.0          1513.03         21693.0
# 2   MIDCPNIFTY FUTURES          105.0             8.32           163.0
# 3        NIFTY FUTURES        18261.0          1988.50         13244.0
# 5        INDEX OPTIONS     17293795.0       1453008.02      17000892.0
# 6     FINNIFTY OPTIONS      1071494.0         91970.16       1051602.0
# 7   MIDCPNIFTY OPTIONS       648628.0         51198.71        644743.0
# 8        NIFTY OPTIONS      4974172.0        540711.89       4858662.0
# 9    BANKNIFTY OPTIONS     10599501.0        769127.26      10445885.0
# 11       STOCK FUTURES       218100.0         17801.12        220384.0
# 13       STOCK OPTIONS       312881.0         26716.18        320013.0
#
#     sell_value_in_Cr  open_contracts  open_contracts_value_in_Cr
# ...

# %%
derivatives.fno_bhav_copy('05-01-2024')
# Out:
#       INSTRUMENT     SYMBOL    EXPIRY_DT  STRIKE_PR OPTION_TYP      OPEN  \
# 0         FUTIDX  BANKNIFTY  25-Jan-2024        0.0         XX  48502.05
# 1         FUTIDX  BANKNIFTY  29-Feb-2024        0.0         XX  48884.30
# 2         FUTIDX  BANKNIFTY  28-Mar-2024        0.0         XX  49100.05
# 3         FUTIDX   FINNIFTY  30-Jan-2024        0.0         XX  21661.45
# 4         FUTIDX   FINNIFTY  27-Feb-2024        0.0         XX  21814.90
# ...          ...        ...          ...        ...        ...       ...
# 58765     OPTSTK  ZYDUSLIFE  28-Mar-2024      790.0         PE      0.00
# 58766     OPTSTK  ZYDUSLIFE  28-Mar-2024      795.0         PE      0.00
# 58767     OPTSTK  ZYDUSLIFE  28-Mar-2024      800.0         PE      0.00
# 58768     OPTSTK  ZYDUSLIFE  28-Mar-2024      805.0         PE      0.00
# 58769     OPTSTK  ZYDUSLIFE  28-Mar-2024      810.0         PE      0.00
#
#            HIGH       LOW     CLOSE  SETTLE_PR  CONTRACTS  VAL_INLAKH  \
# ...

# %%
derivatives.future_price_volume_data('SBIN','FUTSTK',period='1M')
# Out:
#       TIMESTAMP INSTRUMENT SYMBOL    EXPIRY_DT STRIKE_PRICE OPTION_TYPE  \
# 0   05-Jan-2024     FUTSTK   SBIN  25-Jan-2024         0.00          XX
# 1   05-Jan-2024     FUTSTK   SBIN  28-Mar-2024         0.00          XX
# 2   05-Jan-2024     FUTSTK   SBIN  29-Feb-2024         0.00          XX
# 3   04-Jan-2024     FUTSTK   SBIN  25-Jan-2024         0.00          XX
# 4   04-Jan-2024     FUTSTK   SBIN  28-Mar-2024         0.00          XX
# 5   04-Jan-2024     FUTSTK   SBIN  29-Feb-2024         0.00          XX
# 6   03-Jan-2024     FUTSTK   SBIN  25-Jan-2024         0.00          XX
# 7   03-Jan-2024     FUTSTK   SBIN  28-Mar-2024         0.00          XX
# 8   03-Jan-2024     FUTSTK   SBIN  29-Feb-2024         0.00          XX
# 9   02-Jan-2024     FUTSTK   SBIN  25-Jan-2024         0.00          XX
# 10  02-Jan-2024     FUTSTK   SBIN  28-Mar-2024         0.00          XX
# 11  02-Jan-2024     FUTSTK   SBIN  29-Feb-2024         0.00          XX
# ...

# %%
derivatives.participant_wise_open_interest('05-01-2024')
# Out:
#   Client Type  Future Index Long  Future Index Short  Future Stock Long  \
# 0      Client             189489              225431            1662387
# 1         DII              59660               78034              73189
# 2         FII             151352               75099            1424992
# 3         Pro              19446               41383             491586
#
#    Future Stock Short  Option Index Call Long  Option Index Put Long  \
# 0              260822                 4666702                3745783
# 1             2077976                       0                  66532
# 2             1143687                 1132425                1121257
# 3              169669                 1384039                1416403
#
#    Option Index Call Short  Option Index Put Short  Option Stock Call Long  \
# 0                  5120968                 4339977                 1385999
# 1                        0                       0                      89
# ...

# %%
derivatives.participant_wise_trading_volume('05-01-2024')
# Out:
#   Client Type  Future Index Long  Future Index Short  Future Stock Long  \
# 0      Client             184693              188357             459772
# 1         DII               1131                   0              43008
# 2         FII              39443               35257             218100
# 3         Pro             115404              117057             520864
#
#    Future Stock Short  Option Index Call Long  Option Index Put Long  \
# 0              471002                37534438               35976231
# 1               33631                       0                    570
# 2              220384                 8754997                8538798
# 3              516727                55114318               50898011
#
#    Option Index Call Short  Option Index Put Short  Option Stock Call Long  \
# 0                 37682206                36381467                 1202774
# 1                        0                       0                       5
# ...

# %%
# implementing Dashboard

# %%
# necessary libraries required
'''
requests
beautifulsoup
numpy
scipy
pandas
lxml
'''
# Out:
# '\nrequests\nbeautifulsoup\nnumpy\nscipy\npandas\nlxml\n'

# %%
pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 25.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 22.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 62.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.0
#     Uninstalling importlib-metadata-7.0.0:
#       Successfully uninstalled importlib-metadata-7.0.0
# ...
